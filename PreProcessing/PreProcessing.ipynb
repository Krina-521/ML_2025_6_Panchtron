# %% [markdown]
# <h4>Dataset imputation with fillna() & interpolation(polynomial) methods.</h4>

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
# Importing the dataset
df = pd.read_csv('D:/AU/Sem2/ML/Dataset/6.csv')
df.head(3)
# Out:
#               Athlete        Date Day.of.Week   RHR    HRV  Recovery  \
# 0  Athlete 1 Bergdorf  01-01-2022         NaN   NaN    NaN       NaN
# 1  Athlete 1 Bergdorf  01-10-2022      Monday  48.0  120.0      58.0
# 2  Athlete 1 Bergdorf  01-11-2022         NaN   NaN    NaN       NaN
#
#    Sleep.Score  Hours.in.Bed  Hours.of.Sleep  Sleep.Need  ...  Awake..hours.  \
# 0          NaN           NaN             NaN         NaN  ...            NaN
# 1         51.0          6.36            5.62       11.02  ...           0.74
# 2          NaN           NaN             NaN         NaN  ...            NaN
#
#    Sleep.Debt..hours.  Sleep.Consistency  Respiratory.Rate  \
# 0                 NaN                NaN               NaN
# 1                3.21                NaN           11.7188
# 2                 NaN                NaN               NaN
#
#    Total.Cycle.Sleep.Time..hours.  REM.Percentage  Deep.Sleep.Percentage  \
# ...

# %%
# Getting the info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3111 entries, 0 to 3110
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Athlete                         3111 non-null   object
#  1   Date                            3111 non-null   object
#  2   Day.of.Week                     1987 non-null   object
#  3   RHR                             1981 non-null   float64
#  4   HRV                             1981 non-null   float64
#  5   Recovery                        1981 non-null   float64
#  6   Sleep.Score                     1981 non-null   float64
#  7   Hours.in.Bed                    1981 non-null   float64
#  8   Hours.of.Sleep                  1981 non-null   float64
#  9   Sleep.Need                      1981 non-null   float64
#  10  Sleep.Efficiency....            1981 non-null   float64
#  11  Wake.Periods                    1621 non-null   float64
# ...

# %%
# Getting the description of the dataset(Mainly focusing on the Mean & Standard Deviation)
df.describe()
# Out:
#                RHR          HRV     Recovery  Sleep.Score  Hours.in.Bed  \
# count  1981.000000  1981.000000  1981.000000  1981.000000   1981.000000
# mean     59.693084    84.065623    59.546189    76.393236      7.780843
# std       9.003574    36.105314    22.664673    18.553590      1.927197
# min      39.000000    14.000000     1.000000    10.000000      1.050000
# 25%      53.000000    56.000000    43.000000    64.000000      6.580000
# 50%      58.000000    79.000000    61.000000    78.000000      7.800000
# 75%      65.000000   110.000000    77.000000    92.000000      8.960000
# max     120.000000   188.000000    99.000000   100.000000     17.130000
#
#        Hours.of.Sleep   Sleep.Need  Sleep.Efficiency....  Wake.Periods  \
# count     1981.000000  1981.000000           1981.000000   1621.000000
# mean         6.890545     8.910611             88.865724     14.870450
# std          1.652425     1.117639              6.296796      6.613342
# ...

# %%
# Imputing the missing value using interploate method(poylnomial of order 2)
# Meaning 

imputed_df=df.copy()

imputed_df.interpolate(method='polynomial',order=2, inplace=True)
# Out:
# C:\Users\Urjit\AppData\Local\Temp\ipykernel_39744\1072845558.py:6: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   imputed_df.interpolate(method='polynomial',order=2, inplace=True)

# %%
# Imputed dataframe
imputed_df.tail(3)
# imputed_df.isnull().sum()
# Out:
#                 Athlete        Date Day.of.Week  RHR  HRV  Recovery  \
# 3108  Athlete 9 Martino  09-07-2021         NaN  NaN  NaN       NaN
# 3109  Athlete 9 Martino  09-08-2021         NaN  NaN  NaN       NaN
# 3110  Athlete 9 Martino  09-09-2021         NaN  NaN  NaN       NaN
#
#       Sleep.Score  Hours.in.Bed  Hours.of.Sleep  Sleep.Need  ...  \
# 3108          NaN           NaN             NaN         NaN  ...
# 3109          NaN           NaN             NaN         NaN  ...
# 3110          NaN           NaN             NaN         NaN  ...
#
#       Awake..hours.  Sleep.Debt..hours.  Sleep.Consistency  Respiratory.Rate  \
# 3108            NaN                 NaN                NaN               NaN
# 3109            NaN                 NaN                NaN               NaN
# 3110            NaN                 NaN                NaN               NaN
#
#       Total.Cycle.Sleep.Time..hours.  REM.Percentage  Deep.Sleep.Percentage  \
# ...

# %%
imputed_df.isnull().sum()
# Out:
# Athlete                              0
# Date                                 0
# Day.of.Week                       1124
# RHR                                  5
# HRV                                  5
# Recovery                             5
# Sleep.Score                          5
# Hours.in.Bed                         5
# Hours.of.Sleep                       5
# Sleep.Need                           5
# Sleep.Efficiency....                 5
# Wake.Periods                         5
# Sleep.Disturbances                   5
# Latency..min.                        5
# Cycles                               5
# REM.Sleep..hours.                    5
# Deep.Sleep..hours.                   5
# Light.Sleep..hours.                  5
# Awake..hours.                        5
# Sleep.Debt..hours.                   5
# Sleep.Consistency                   30
# Respiratory.Rate                     5
# Total.Cycle.Sleep.Time..hours.       5
# REM.Percentage                       5
# ...

# %%
# For the rows who wasn't get imputed for the missing values
imputed_df.fillna(method='bfill', inplace=True)
# Out:
# C:\Users\Urjit\AppData\Local\Temp\ipykernel_39744\2070102801.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   imputed_df.fillna(method='bfill', inplace=True)

# %%
imputed_df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Urjit\AppData\Local\Temp\ipykernel_39744\339839546.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   imputed_df.fillna(method='ffill', inplace=True)

# %%
imputed_df.head(3)
# Out:
#               Athlete        Date Day.of.Week        RHR         HRV  \
# 0  Athlete 1 Bergdorf  01-01-2022      Monday  48.000000  120.000000
# 1  Athlete 1 Bergdorf  01-10-2022      Monday  48.000000  120.000000
# 2  Athlete 1 Bergdorf  01-11-2022    Thursday  50.664742  119.003574
#
#    Recovery  Sleep.Score  Hours.in.Bed  Hours.of.Sleep  Sleep.Need  ...  \
# 0    58.000    51.000000      6.360000        5.620000   11.020000  ...
# 1    58.000    51.000000      6.360000        5.620000   11.020000  ...
# 2    57.443    50.885278      6.227324        5.488423   10.737243  ...
#
#    Awake..hours.  Sleep.Debt..hours.  Sleep.Consistency  Respiratory.Rate  \
# 0       0.740000            3.210000               37.0          11.71880
# 1       0.740000            3.210000               37.0          11.71880
# 2       0.743142            2.709815               37.0          12.30694
#
#    Total.Cycle.Sleep.Time..hours.  REM.Percentage  Deep.Sleep.Percentage  \
# ...

# %%
imputed_df.isnull().sum()
# Out:
# Athlete                           0
# Date                              0
# Day.of.Week                       0
# RHR                               0
# HRV                               0
# Recovery                          0
# Sleep.Score                       0
# Hours.in.Bed                      0
# Hours.of.Sleep                    0
# Sleep.Need                        0
# Sleep.Efficiency....              0
# Wake.Periods                      0
# Sleep.Disturbances                0
# Latency..min.                     0
# Cycles                            0
# REM.Sleep..hours.                 0
# Deep.Sleep..hours.                0
# Light.Sleep..hours.               0
# Awake..hours.                     0
# Sleep.Debt..hours.                0
# Sleep.Consistency                 0
# Respiratory.Rate                  0
# Total.Cycle.Sleep.Time..hours.    0
# REM.Percentage                    0
# Deep.Sleep.Percentage             0
# Restorative.Sleep..hours.         0
# ...

# %%
imputed_df.describe()
# Out:
#                RHR          HRV     Recovery  Sleep.Score  Hours.in.Bed  \
# count  3111.000000  3111.000000  3111.000000  3111.000000   3111.000000
# mean     58.970981    99.351279    69.013681    68.665009      6.272099
# std      13.326506    84.559479    50.792322    39.837498      7.441607
# min      -4.001641  -130.778220  -102.850659  -151.099903    -48.700159
# 25%      53.000000    55.000000    43.041425    60.000000      6.210000
# 50%      58.000000    82.208677    65.600832    76.000000      7.680000
# 75%      65.000000   120.000000    84.204933    91.171154      9.038014
# max     156.265696   702.982977   385.099968   153.493550     17.130000
#
#        Hours.of.Sleep   Sleep.Need  Sleep.Efficiency....  Wake.Periods  \
# count     3111.000000  3111.000000           3111.000000   3111.000000
# mean         5.502480     8.959769             88.792728     13.417374
# std          7.299589     1.461908             14.600716     13.408242
# ...

# %%
mean_diff=df.describe().loc['mean']-imputed_df.describe().loc['mean']
std_diff=df.describe().loc['std']-imputed_df.describe().loc['std']

diff_df=pd.DataFrame([mean_diff,std_diff],index=['mean_diff','std_diff'])

print(diff_df.to_string())
# Out:
#                 RHR        HRV   Recovery  Sleep.Score  Hours.in.Bed  Hours.of.Sleep  Sleep.Need  Sleep.Efficiency....  Wake.Periods  Sleep.Disturbances  Latency..min.    Cycles  REM.Sleep..hours.  Deep.Sleep..hours.  Light.Sleep..hours.  Awake..hours.  Sleep.Debt..hours.  Sleep.Consistency  Respiratory.Rate  Total.Cycle.Sleep.Time..hours.  REM.Percentage  Deep.Sleep.Percentage  Restorative.Sleep..hours.  Restorative.Sleep....       RSI
# mean_diff  1.159566 -11.965588  -7.228311     7.367306      1.473637        1.355008   -0.011862              0.075118      1.183913            0.919278      -0.487844  1.267732           0.383686            0.289910             0.677409       0.118588            0.047268         -25.359858          0.137346                        1.403116        5.285605               0.669430                   0.735826               6.407659 -0.008204
# ...

# %%
diff_df_T = diff_df.T
bar_width = 0.4
x = np.arange(len(diff_df_T))

fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns

# Mean Difference Plot
axes[0].bar(diff_df.columns, diff_df.loc['mean_diff'], color='skyblue', edgecolor='black')
axes[0].axhline(0, color='red', linestyle='--', linewidth=1)   # Add a horizontal line at 0
axes[0].set_title("Mean Differences After Imputation")
axes[0].set_xlabel("Columns")
axes[0].set_ylabel("Mean Difference")
axes[0].tick_params(axis='x', rotation=90)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Standard Deviation Difference Plot
axes[1].bar(diff_df.columns, diff_df.loc['std_diff'], color='lightcoral', edgecolor='black')
axes[1].axhline(0, color='red', linestyle='--', linewidth=1)
axes[1].set_title("Standard Deviation Differences After Imputation")
axes[1].set_xlabel("Columns")
axes[1].set_ylabel("Standard Deviation Difference")
axes[1].tick_params(axis='x', rotation=90)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
imputed_df.to_csv('D:/AU/Sem2/ML/HandsOn Prac/Project/ML_2025_6_Panchtron/Dataset/imputed_interpolate.csv',index=False)

# %% [markdown]
# <h4>Dataset imputation with MICE(Multivariate Imputation by Chained Equations).</h4>

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
imputed2_df = df.copy()
imputed2_df.isna().sum()
# Out:
# Athlete                              0
# Date                                 0
# Day.of.Week                       1124
# RHR                               1130
# HRV                               1130
# Recovery                          1130
# Sleep.Score                       1130
# Hours.in.Bed                      1130
# Hours.of.Sleep                    1130
# Sleep.Need                        1130
# Sleep.Efficiency....              1130
# Wake.Periods                      1490
# Sleep.Disturbances                1130
# Latency..min.                     1130
# Cycles                            1130
# REM.Sleep..hours.                 1130
# Deep.Sleep..hours.                1130
# Light.Sleep..hours.               1130
# Awake..hours.                     1130
# Sleep.Debt..hours.                1130
# Sleep.Consistency                 1401
# Respiratory.Rate                  1134
# Total.Cycle.Sleep.Time..hours.    1130
# REM.Percentage                    1130
# ...

# %%
imputed2_df.head(3)
# Out:
#               Athlete        Date Day.of.Week   RHR    HRV  Recovery  \
# 0  Athlete 1 Bergdorf  01-01-2022         NaN   NaN    NaN       NaN
# 1  Athlete 1 Bergdorf  01-10-2022      Monday  48.0  120.0      58.0
# 2  Athlete 1 Bergdorf  01-11-2022         NaN   NaN    NaN       NaN
#
#    Sleep.Score  Hours.in.Bed  Hours.of.Sleep  Sleep.Need  ...  Awake..hours.  \
# 0          NaN           NaN             NaN         NaN  ...            NaN
# 1         51.0          6.36            5.62       11.02  ...           0.74
# 2          NaN           NaN             NaN         NaN  ...            NaN
#
#    Sleep.Debt..hours.  Sleep.Consistency  Respiratory.Rate  \
# 0                 NaN                NaN               NaN
# 1                3.21                NaN           11.7188
# 2                 NaN                NaN               NaN
#
#    Total.Cycle.Sleep.Time..hours.  REM.Percentage  Deep.Sleep.Percentage  \
# ...

# %%
# missing_mask=imputed2_df.isna()

# %%
numeric_cols = df.select_dtypes(include=['number']).columns

# Step 2: Apply IterativeImputer only on numeric columns
imputer = IterativeImputer(max_iter=10, random_state=0)
imputed_values = imputer.fit_transform(df[numeric_cols])

# Step 3: Replace only the numeric missing values in the original DataFrame
df[numeric_cols] = imputed_values

# Step 4: Check results
df.head()

df.to_csv('D:/AU/Sem2/ML/HandsOn Prac/Project/ML_2025_6_Panchtron/Dataset/imputed_MICE.csv',index=False)

# %%
df.isna().sum()
# Out:
# Athlete                              0
# Date                                 0
# Day.of.Week                       1124
# RHR                                  0
# HRV                                  0
# Recovery                             0
# Sleep.Score                          0
# Hours.in.Bed                         0
# Hours.of.Sleep                       0
# Sleep.Need                           0
# Sleep.Efficiency....                 0
# Wake.Periods                         0
# Sleep.Disturbances                   0
# Latency..min.                        0
# Cycles                               0
# REM.Sleep..hours.                    0
# Deep.Sleep..hours.                   0
# Light.Sleep..hours.                  0
# Awake..hours.                        0
# Sleep.Debt..hours.                   0
# Sleep.Consistency                    0
# Respiratory.Rate                     0
# Total.Cycle.Sleep.Time..hours.       0
# REM.Percentage                       0
# ...

# %%
original_df = pd.read_csv('D:/AU/Sem2/ML/HandsOn Prac/Project/ML_2025_6_Panchtron/Dataset/6.csv')
imputed_df1 = pd.read_csv('D:/AU/Sem2/ML/HandsOn Prac/Project/ML_2025_6_Panchtron/Dataset/imputed_interpolate.csv') 
imputed_df2 = pd.read_csv('D:/AU/Sem2/ML/HandsOn Prac/Project/ML_2025_6_Panchtron/Dataset/imputed_MICE.csv')

missing_before = original_df.isna().sum()
missing_after_1 = imputed_df1.isna().sum()
missing_after_2 = imputed_df2.isna().sum()

missing_comparison = pd.DataFrame({
    'Original': missing_before,
    'Imputed1': missing_after_1,
    'Imputed2': missing_after_2
})

# Step 3: Focus only on columns that had missing values initially
missing_comparison = missing_comparison.loc[missing_before[missing_before > 0].index]

# Step 4: Melt for seaborn
missing_comparison = missing_comparison.reset_index().melt(id_vars='index',
                                                          var_name='Stage',
                                                          value_name='Missing Values')

# Step 5: Plot using seaborn
plt.figure(figsize=(14, 6))
sns.barplot(data=missing_comparison, x='index', y='Missing Values', hue='Stage', palette=['#FF6347', '#4682B4', '#32CD32'])

# Step 6: Adjust aesthetics
plt.title('Missing Values: Original vs Imputed1 vs Imputed2', fontsize=16)
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Number of Missing Values', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Stage')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
imputed_df1.isna().sum()
# Out:
# Athlete                           0
# Date                              0
# Day.of.Week                       0
# RHR                               0
# HRV                               0
# Recovery                          0
# Sleep.Score                       0
# Hours.in.Bed                      0
# Hours.of.Sleep                    0
# Sleep.Need                        0
# Sleep.Efficiency....              0
# Wake.Periods                      0
# Sleep.Disturbances                0
# Latency..min.                     0
# Cycles                            0
# REM.Sleep..hours.                 0
# Deep.Sleep..hours.                0
# Light.Sleep..hours.               0
# Awake..hours.                     0
# Sleep.Debt..hours.                0
# Sleep.Consistency                 0
# Respiratory.Rate                  0
# Total.Cycle.Sleep.Time..hours.    0
# REM.Percentage                    0
# Deep.Sleep.Percentage             0
# Restorative.Sleep..hours.         0
# ...

# %%
imputed_df2.isna().sum()
# Out:
# Athlete                              0
# Date                                 0
# Day.of.Week                       1124
# RHR                                  0
# HRV                                  0
# Recovery                             0
# Sleep.Score                          0
# Hours.in.Bed                         0
# Hours.of.Sleep                       0
# Sleep.Need                           0
# Sleep.Efficiency....                 0
# Wake.Periods                         0
# Sleep.Disturbances                   0
# Latency..min.                        0
# Cycles                               0
# REM.Sleep..hours.                    0
# Deep.Sleep..hours.                   0
# Light.Sleep..hours.                  0
# Awake..hours.                        0
# Sleep.Debt..hours.                   0
# Sleep.Consistency                    0
# Respiratory.Rate                     0
# Total.Cycle.Sleep.Time..hours.       0
# REM.Percentage                       0
# ...

# %% [markdown]
# #### Distribution Of Data

# %%
df=pd.read_csv('D:/AU/Sem2/ML/HandsOn Prac/Project/ML_2025_6_Panchtron/Dataset/6.csv')
imputed_interpolate=pd.read_csv('D:/AU/Sem2/ML/HandsOn Prac/Project/ML_2025_6_Panchtron/Dataset/imputed_interpolate.csv')
imputed_MICE=pd.read_csv('D:/AU/Sem2/ML/HandsOn Prac/Project/ML_2025_6_Panchtron/Dataset/imputed_MICE.csv')

# %%
numeric_cols = df.select_dtypes(include='number').columns

# Plotting
fig, axes = plt.subplots(nrows=len(numeric_cols), ncols=3, figsize=(15, 5 * len(numeric_cols)))
fig.subplots_adjust(hspace=0.3)

datasets = {
    'Original': df,
    'Interpolate Method': imputed_interpolate,
    'MICE': imputed_MICE
}

# Plot each column across all datasets
for i, col in enumerate(numeric_cols):
    for j, (name, dataset) in enumerate(datasets.items()):
        sns.histplot(dataset[col], kde=True, ax=axes[i, j])
        axes[i, j].set_title(f'{col} - {name}')
        axes[i, j].set_xlabel('')

plt.tight_layout()
plt.show()
